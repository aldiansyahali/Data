# %% [markdown]
# <a href="https://colab.research.google.com/github/aldiansyahali/Data/blob/main/BERTScore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==4.0.0-rc1
# !pip install bert-score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.4 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17395 sha256=9b5be9f59244046408aa3c41cc867b04b363d690e535d18c9ae47e6f19f77191
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
from bert_score import score

#List Pertanyaan
#1. apa judul pada artikel ini?
#2. siapa penulis pada artikel ini?
#3. kapan artikel ini diterbitkan?
#4. apa tujuan utama dari penelitian ini?
#5. apa batasan penelitian dalam artikel ini?
#6. apa kesimpulan lengkap dari artikel ini?
#7. Apa saran untuk penelitian lebih lanjut yang diberikan oleh penulis?
#8. Bagaimana hasil penelitian ini dibandingkan dengan penelitian sebelumnya?


# Data sesuai referensi
references = [
    "A RAG-based Question Answering System Proposal for Understanding Islam: MufassirQAS LLM.",
    "Ahmet Yusuf Alan, Enis Karaarslan, Omer Aydin.",
    "January 2024.",
    "This study uses a vector database-based Retrieval Augmented Generation (RAG) approach to enhance the accuracy and transparency of LLMs. Our question-answering system is called “MufassirQAS''. We created a database consisting of several open-access books that include Turkish context. These books contain Turkish translations and interpretations of Islam. This database is utilized to answer religion-related questions and ensure our answers are trustworthy",
    "possibility of biases in the dataset and the difficulty of ensuring religious sensitivity in the responses. We are also aware of the security vulnerabilities of LLMs, which can lead to unexpected responses to prompts.",
    "This study showed that the Retrieval Augmented Generation (RAG) approach can prevent hallucination in LLMs. We developed the MufassirQAS system that utilizes this concept for understanding Islam.",
    "In the future, we plan to test this limitation and develop smaller and more sustainable models that are highly efficient and specialized in understanding religion and answering related questions.",
    "MufassirQAS and ChatGPT are also tested with sensitive questions. We got better performance with our system. Study and enhancements are still in progress. Results and future works are given"
]

# hasil chatbot
predictions = [
    "ARAG-based Question Answering System Proposal for Understanding Islam: MufassirQASLLM.",
    "Alan, A.Y., Karaarslan, E., dan Aydin, O.",
    "Januari 2024.",
    "Tujuan utama dari penelitian yang disebut dalam artikel A RAG-based Question Answering System Proposal for Understanding Islam: MufassirQASLLM adalah untuk mengusulkan sistem tanya jawab berbasis RAG yang dapat membantu dalam memahami agama Islam, khususnya dalam interpretasi Al-Quran, Hadis, dan sumber-sumber Islam lainnya. ",
    "kemungkinan bias dalam dataset, kesulitan dalam memastikan sensitivitas agama dalam respons, dan kerentanan keamanan dari LLMs yang dapat menyebabkan respons yang tak terduga terhadap permintaan.",
    "penelitian ini mencoba untuk mengatasi tantangan dalam pemahaman agama, khususnya Islam, dengan mengusulkan sistem tanya jawab berbasis RAG (Retrieval Augmented Generation) yang spesifik untuk memahami Islam. Metode ini bertujuan untuk mencegah terjadinya halusinasi dalam Large Language Models (LLMs) yang seringkali menghasilkan informasi yang tidak benar. Dengan pendekatan ini, diharapkan bahwa sistem informasi Islamic-answerings akan lebih akurat dan dapat memberikan jawaban yang benar terkait agama Islam sesuai dengan sumber-sumber Islam yang akan digunakan.",
    "Saran untuk penelitian lebih lanjut yang diberikan oleh penulis adalah untuk menguji batasan tersebut dan mengembangkan model-model yang lebih kecil dan lebih berkelanjutan yang sangat efisien dan sangat spesialis dalam memahami agama dan menjawab pertanyaan terkait.",
    "MufassirQAS memiliki keunggulan dalam memberikan jawaban yang lebih pasti dan jelas dibandingkan dengan ChatGPT yang cenderung memberikan jawaban yang lebih samar dan tidak pasti."
]

# Menghitung BERTScore dengan model multibahasa
P, R, F1 = score(predictions, references, lang="multilingual", verbose=True)

# Menampilkan hasil rata-rata
print(f"Average Precision: {P.mean().item()}")
print(f"Average Recall: {R.mean().item()}")
print(f"Average F1: {F1.mean().item()}")

# Menampilkan hasil individual untuk setiap pasangan
for i, (p, r, f) in enumerate(zip(P, R, F1)):
    print(f"Pair {i + 1} - Precision: {p.item()}, Recall: {r.item()}, F1: {f.item()}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
from bert_score import score

#List Pertanyaan
#1. apa judul pada artikel ini?
#2. siapa penulis pada artikel ini?
#3. kapan artikel ini diterbitkan?
#4. apa tujuan utama dari penelitian ini?
#5. apa batasan penelitian dalam artikel ini?
#6. apa kesimpulan dari artikel ini?
#7. Apa saran untuk penelitian lebih lanjut yang diberikan oleh penulis?
#8. Bagaimana hasil penelitian ini dibandingkan dengan penelitian sebelumnya?

# Daftar referensi dan prediksi
references = [
    "Design a Smart Solar Tracker to Increase Energy Output Power Generated in Solar Home System.",
    "Yuli Mafendro Dedet Eka Saputra, Mochammad Tendi Noer Ramadhan, Azzahra Maulida, Budi Santoso, dan Ismail Basri.",
    "Volume : 6, Number : 1, 2024.",
    "Penelitian ini mengusulkan penggunaan smart solar tracker untuk meningkatkan daya yang dihasilkan  oleh panel surya",
    "Smart solar tracker dirancang dengan mengintegrasikan teknologi IoT dan diterapkan pada Solar Home System. Alat ini tidak hanya mengoptimalkan sudut kemiringan panel surya secara otomatis, tetapi juga memungkinkan pemantauan jarak jauh terhadap kinerja panel surya melalui IoT. Pengukuran parameter seperti sudut panel, tegangan, dan arus dilakukan",
    "Smart Solar tracker yang dirancang menggunakan sistem kontrol otomatis dan IoT bekerja dengan baik sesuai fungsi, sehingga panel surya bergerak sesuai waktu yang telah ditentukan dan mengarah tepat ke matahari. Daya panel tanpa smart solar tracker menghasilkan daya sekitar 8.9W terjadi di sekitar pukul 11.00 WIB dengan posisi panel surya sebesar 35 derajat. Sedangkan daya panel surya menggunakan smart solar tracker sebesar 9.85W terjadi di sekitar pukul 11.00 WIB dengan sudut panel surya 70 derajat.",
    "jawaban tidak tersedia didalam konteks yang diberikan",
    "Solar tracker Cerdas dirancang dengan sistem IoT (Internet of Things) sederhana yang berfungsi sebagai monitoring dan controling panel surya pada Solar Home System (SHS). Solar tracker merupakan cara yang efektif untuk meningkatkan output energi yang dihasilkan dari sistem tenaga surya sehingga dapat menghasilkan penghematan biaya yang signifikan dalam jangka panjang, dan memaksimalkan lahan yang terbatas untuk memproduksi daya yang besar. Sebelumnya sudah ada penelitian mengenai solar tracker cerdas ini, namun belum ada yang mengaplikasikannya pada Solar Home System dengan jenis single axis dan berbasis IoT."

]
predictions = [
    "Design a Smart Solar Tracker to Increase Energy Output Power Generated in Solar Home System.",
    "Yuli Mafendro Dedet Eka Saputra, Mochammad Tendi Noer Ramadhan, Azzahra Maulida, Budi Santoso, Ismail Basri.",
    "Artikel ini diterbitkan pada Volume 6, Nomor 1, tahun 2024.",
    "Penelitian ini bertujuan untuk merancang Solar Tracker cerdas yang dapat meningkatkan daya hasil energi yang dihasilkan dalam Sistem Rumah Solar.",
    "Fokus pada pengembangan smart solar tracker untuk meningkatkan efisiensi daya yang dihasilkan oleh panel surya. Pengukuran parameter seperti sudut panel, tegangan, dan arus dilakukan untuk memantau kinerja panel surya. Perangkat smart solar tracker diintegrasikan dengan teknologi IoT untuk memungkinkan pemantauan jarak jauh terhadap kinerja panel surya. Uji coba dilakukan pada Solar Home System dengan perbandingan output daya antara panel surya yang menggunakan smart solar tracker dan yang tidak. Penelitian fokus pada peningkatan daya output panel surya dengan bantuan smart solar tracker.",
    "Penelitian ini mengusulkan penggunaan smart solar tracker untuk meningkatkan daya yang dihasilkan oleh panel surya. Smart solar tracker dirancang dengan mengintegrasikan teknologi IoT dan diterapkan pada Solar Home System. Hasil pengujian menunjukkan bahwa pemasangan smart solar tracker meningkatkan daya output panel surya dibandingkan dengan panel surya tanpa smart solar tracker. Misalnya, pada pukul 11.00 WIB, panel surya dengan smart solar tracker menghasilkan daya sebesar 9.85W dengan sudut panel 70 derajat, sementara panel surya tanpa smart solar tracker hanya menghasilkan daya sebesar 8.9W dengan sudut panel 35 derajat. Kesimpulan dari penelitian ini adalah penggunaan smart solar tracker dapat signifikan meningkatkan efisiensi sistem PV surya dengan memastikan panel surya selalu berorientasi pada matahari untuk pemaparan maksimum, yang pada akhirnya menghasilkan peningkatan daya output panel surya.",
    "Konteks yang anda berikan tidak menunjukkan jawaban yang sesuai",
    "Penelitian ini menunjukkan keterbaruan dalam penggunaan smart solar tracker yang terintegrasi dengan teknologi IoT pada Solar Home System. Dalam penelitian sebelumnya, peneliti juga telah membahas penggunaan solar tracker, namun penelitian ini menawarkan inovasi baru dengan menggabungkan teknologi IoT untuk monitoring jarak jauh terhadap kinerja panel surya. Dengan demikian, penelitian ini memberikan kontribusi baru dalam pengembangan sistem pelacakan surya untuk meningkatkan efisiensi energi dalam memanfaatkan energi surya."
]

# Menghitung BERTScore untuk semua pasangan
P, R, F1 = score(predictions, references, lang="id", verbose=True)

# Menampilkan hasil rata-rata
print(f"Average Precision: {P.mean().item()}")
print(f"Average Recall: {R.mean().item()}")
print(f"Average F1: {F1.mean().item()}")

# Menampilkan hasil individual untuk setiap pasangan
for i, (p, r, f) in enumerate(zip(P, R, F1)):
    print(f"Pair {i + 1} - Precision: {p.item()}, Recall: {r.item()}, F1: {f.item()}")
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 9.35 seconds, 0.86 sentences/sec
# Average Precision: 0.8255481719970703
# Average Recall: 0.8341176509857178
# Average F1: 0.8296679258346558
# Pair 1 - Precision: 1.0, Recall: 1.0, F1: 1.0
# Pair 2 - Precision: 0.974806010723114, Recall: 0.968330979347229, F1: 0.9715577363967896
# Pair 3 - Precision: 0.764074444770813, Recall: 0.7913968563079834, F1: 0.7774957418441772
# Pair 4 - Precision: 0.8279303908348083, Recall: 0.8401648998260498, F1: 0.8340027928352356
# Pair 5 - Precision: 0.7764947414398193, Recall: 0.7833370566368103, F1: 0.779900848865509
# Pair 6 - Precision: 0.757011890411377, Recall: 0.8076863884925842, F1: 0.7815285921096802
# Pair 7 - Precision: 0.7915586233139038, Recall: 0.7673925161361694, F1: 0.7792882919311523
# ...

# %%
# Daftar referensi dan prediksi
references = [
    "PENERAPAN RETRIEVAL AUGEMENTED GENERATION MENGGUNAKAN LANGCHAIN DALAM PENGEMBANGAN SISTEM TANYA JAWAB HADIS BERBASIS WEB",
    "Hasil pengujian menunjukkan bahwa sistem ini mampu mencapai nilai rata-rata BERTScore sebesar 0.796.",
    "perolehan persentase akurasi sebesar 89,4%.",
    "Muhammad Irfan Syah, Nazruddin Safaat Harahap, Novriyanto, Suwanto Sanjaya.",
    "embedding oleh OpenAI Embeddings.",
    "Pada pengujian BERTScore didapatkanlah nilai rata rata dari Skor F1 sebesar 0.7962 dari 0.0 hingga 1.0. Pada uji evaluasi kualitas jawaban, peresentase indeks sebesar 89,4%.",
    "tambahan dari kitab Asbabun Wurud. Ini akan memperluas cakupan pemahaman sistem terhadap konteks dan makna hadis",
    "total pertanyaan yaitu 10",
    "Penelitian ini berfokus untuk meningkatkan kemampuan sistem dalam menghasilkan jawaban seputar 9 kitab hadis",
    " Dalam konteks penggunaan LLMs, terdapat perbandingan dengan model yang disesuaikan (fine-tuned models), yang merupakan model bahasa yang lebih kecil dan dilatih sebelumnya kemudian disesuaikan lebih lanjut pada dataset yang lebih kecil untuk meningkatkan kinerjanya pada tugas tersebut"
]
predictions = [
    "Penelitian ini memiliki judul Penerapan Retrieval Augmented Generation Menggunakan LangChain dalam Sistem Tanya Jawab Hadis Berbasis Web.",
    "Berdasarkan hasil penelitian, nilai rata-rata dari Skor BERTScore F1 adalah 0.7962 dari rentang 0.0 hingga 1.0.",
    "Persentase akurasi jawaban yang dihasilkan oleh sistem adalah sebesar 89,4%.",
    "Nama peneliti dalam penelitian Penerapan Retrieval Augmented Generation Menggunakan LangChain dalam Pengembangan Sistem Tanya Jawab Hadis Berbasis Web adalah: Muhammad Irfan Syah, Nazruddin Safaat Harahap, Novriyanto, Suwanto Sanjaya.",
    "model embedding yang digunakan adalah OpenAI Embeddings.",
    "Persentase hasil pengujian menunjukkan nilai akurasi jawaban sebesar 89,4%, dengan nilai rata-rata Skor F1 dari pengujian BERTScore sebesar 0.7962.",
    "Dalam penelitian ini, untuk memperluas pemahaman sistem terhadap konsep makna hadis, peneliti akan menggunakan kitab Asbabun Wurud.",
    "Ada total 10 pertanyaan",
    "Dalam penelitian yang dilakukan, jumlah total hadis yang dijadikan database adalah 9 kitab hadis.",
    "Fine-tunned models digunakan untuk meningkatkan kemampuan sistem dalam menghasilkan jawaban yang lebih informatif."
]

# Menghitung BERTScore untuk semua pasangan
P, R, F1 = score(predictions, references, lang="en", verbose=True)

# Menampilkan hasil rata-rata
print(f"Average Precision: {P.mean().item()}")
print(f"Average Recall: {R.mean().item()}")
print(f"Average F1: {F1.mean().item()}")

# Menampilkan hasil individual untuk setiap pasangan
for i, (p, r, f) in enumerate(zip(P, R, F1)):
    print(f"Pair {i + 1} - Precision: {p.item()}, Recall: {r.item()}, F1: {f.item()}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 22.98 seconds, 0.44 sentences/sec
# Average Precision: 0.867973804473877
# Average Recall: 0.8836291432380676
# Average F1: 0.875073254108429
# Pair 1 - Precision: 0.8467397093772888, Recall: 0.8452379703521729, F1: 0.8459881544113159
# Pair 2 - Precision: 0.850237250328064, Recall: 0.8629235625267029, F1: 0.8565334677696228
# Pair 3 - Precision: 0.8576396107673645, Recall: 0.9003453850746155, F1: 0.8784737586975098
# Pair 4 - Precision: 0.8202476501464844, Recall: 0.9510308504104614, F1: 0.8808109760284424
# ...
